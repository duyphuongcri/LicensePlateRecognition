# %%
import Automold as am
import Helpers as hp
import cv2

# %%
path = '/home/truongdongdo/Documents/GitKraken/LicensePlateRecognition/magic/data_test/*.png'
images= hp.load_images(path)

# %%
hp.visualize(images, column=3, fig_size=(20,10))

# %%
print(len(images))
# Out:
# 12

# %%
test_image = images[1]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(test_image)

# %%
rainy_images= am.add_rain(images) 
hp.visualize(rainy_images, column=3)
# plt.imshow(rainy_images)

# %%
save_img = cv2.cvtColor(rainy_images,cv2.COLOR_RGB2BGR)
dark_images= save_img[1] * 0.2
# save_img = cv2.cvtColor(rainy_images,cv2.COLOR_RGB2BGR)
hp.visualize(dark_images, column=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-4fe4e9dbfad1> in <module>
# ----> 1 save_img = cv2.cvtColor(rainy_images,cv2.COLOR_RGB2BGR)
#       2 dark_images= save_img[1] * 0.2
#       3 # save_img = cv2.cvtColor(rainy_images,cv2.COLOR_RGB2BGR)
#       4 hp.visualize(dark_images, column=3)
#
# TypeError: src is not a numpy array, neither a scalar

# %%
rainy_images_2= am.add_rain(images, rain_type='drizzle', slant=-10) 
hp.visualize(rainy_images, column=3)

# %%
save_path = '/home/truongdongdo/Documents/GitKraken/LicensePlateRecognition/magic/rain_img/1.png'
save_img = cv2.cvtColor(rainy_images,cv2.COLOR_RGB2BGR)

cv2.imwrite(save_path,save_img)

# %%
size(save_img)

# %%
flare_images= am.add_sun_flare(images[4:7]) 
hp.visualize(flare_images, column=3)
